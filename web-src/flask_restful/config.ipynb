# %%
# import necessary libraries
from flask import (
    Flask,
    render_template,
    jsonify,
    request)
import pandas as pd
from flask_sqlalchemy import SQLAlchemy

# %%
#Innit app
app = Flask(__name__)

password = os.environ.get('DB_PASS')
app.config['SQLALCHEMY_DATABASE_URI'] = "postgres://postgres:"+password+"@localhost/Kanye"
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
db = SQLAlchemy(app)

class discography(db.Model):
    __tablename__ = 'discographies'
    
    id = db.Column(db.Integer, primary_key=True)
    album = db.Column(db.String(100))
    song = db.Column(db.String(100))
    sentiment = db.Column(db.Float)
    rating = db.Column(db.String(50))
    
    def __repr__(self):
        return '<discography %r>' % (self.album)

@app.before_first_request
def setup():
    db.drop_all()
    db.create_all()

@app.route("/datacsv", methods=["GET","POST"])
def datacsv():
    json_=request.json
    new = pd.read_csv('/web-src/js/wipcsv.csv')
    json_vector=new.transform(json_)
    query=pd.DataFrame(json_vector)
    discography = regr.predict(query)
    data = {'discography':list({{discography}})}
    return jsonify(data)
        
#Run Server
if __name__ =='__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Public\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
pd.read_csv('wipcsv.csv')
# Out:
#                  Album                                       Song  Sentiment  \
# 0      College Dropout                                      Intro        0.2
# 1      College Dropout                              We Don't Care       -0.3
# 2      College Dropout                             Graduation Day       -0.2
# 3      College Dropout                             All Falls Down       -0.6
# 4      College Dropout                              I'll Fly Away        0.2
# 5      College Dropout                                  Spaceship       -0.5
# 6      College Dropout                                Jesus Walks        0.0
# 7      College Dropout                          Never Let Me Down        0.0
# 8      College Dropout                                Get Em High        0.0
# 9      College Dropout                               Workout Plan        0.0
# 10     College Dropout                       The New Workout Plan        0.2
# ...
