# %%
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types
import pandas as pd

# Instantiates a client
client = language.LanguageServiceClient()

# %%
Lyrics_csv = "../Kanye-Album-Project/updated_kanye_discography.csv"
Lyrics_csv_df = pd.read_csv(Lyrics_csv)
Lyrics_csv_df.head(20)
# Out:
#               album  year_released                    song  \
# 0   College Dropout           2004                   Intro
# 1   College Dropout           2004           We Don't Care
# 2   College Dropout           2004          Graduation Day
# 3   College Dropout           2004          All Falls Down
# 4   College Dropout           2004           I'll Fly Away
# 5   College Dropout           2004               Spaceship
# 6   College Dropout           2004             Jesus Walks
# 7   College Dropout           2004       Never Let Me Down
# 8   College Dropout           2004             Get Em High
# 9   College Dropout           2004            Workout Plan
# 10  College Dropout           2004    The New Workout Plan
# 11  College Dropout           2004               Slow Jamz
# 12  College Dropout           2004  Breathe In Breathe Out
# 13  College Dropout           2004    School Spirit Skit 1
# 14  College Dropout           2004           School Spirit
# 15  College Dropout           2004    School Spirit Skit 2
# 16  College Dropout           2004          Lil Jimmy Skit
# 17  College Dropout           2004               Two Words
# 18  College Dropout           2004        Through The Wire
# 19  College Dropout           2004         Family Business
#
#                                                 lyric
# 0   . . . . Kanye, can I talk to you for a minute?...
# 1   . . . . . . And all my people thats drug deali...
# 2   . . . . What in the fuck was that Kanye. . I t...
# 3   . . . . . . Oh when it all, it all falls down....
# 4   . . . . Some glad morning when this life is ov...
# 5   . . . . . . I've been workin' this graveshift ...
# 6   . . . . Yo, we at war. We at war with terroris...
# 7   . . . . . . Yeah Grandmama. . Told you I won't...
# 8   . . . . . I'm trying to catch the beat, uh. I'...
# 9   . . . . . . Ay Wussup gurl. . Heyy gurl . . He...
# 10  . . . . . . You just popped in the Kanye West....
# 11  . . . . . . Are you gonna be?. . Say that you'...
# 12  . . . . . . Yeah, breathe in, breathe out. . I...
# 13  . . . . Now beat that. . And your mothers sayi...
# 14  . . . . Now beat that. . And your mothers sayi...
# 15  . . . . You keep it going man, you keep those ...
# 16  . . . . . . Hey Jimmy where you going?. . I do...
# 17  . . . . . . We in the streets playa, getcha ma...
# 18  . . . . Yo G they can't stop me from rapping c...
# 19  . . . . . . How's your son? (all, all, all the...

# %%
# The text to analyze
text = u'In the night, I hear them talk the coldest story ever told Somewhere far along this road, he lost his soul To a woman so heartlessHow could you be so heartless Oh, how could you be so heartless?'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# %%
# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

# %%
print('Text: {}'.format(text))
print('Sentiment: {}'.format(sentiment.score))
# Out:
# Text: In the night, I hear them talk the coldest story ever told Somewhere far along this road, he lost his soul To a woman so heartlessHow could you be so heartless Oh, how could you be so heartless?
# Sentiment: -0.8999999761581421
